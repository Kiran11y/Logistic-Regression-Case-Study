# %% [markdown]
# ### 1. Import The Important libraries

# %%
## CODE HERE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Import the Dataset

# %%
## CODE HERE
df = pd.read_csv("framingham.csv")
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
## CODE HERE

# %% [markdown]
# ### check that if there are any null values in dataframe

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %% [markdown]
# ### 3A.impute the null values in education column

# %%
##CODE HERE
df["education"].mode()[0]
# Out:
# 1.0

# %%
##CODE HERE
df["education"].fillna(df['education'].mode()[0],inplace=True)
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education            0
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %% [markdown]
# ### 3B. Null value imputation for cigsperday column

# %%
df["cigsPerDay"].fillna(df['cigsPerDay'].mean(),inplace=True)

# %% [markdown]
# ### 3B. Null value imputation for BPMeds column

# %%
##CODE HERE
df["BPMeds"].fillna(df['BPMeds'].mode()[0],inplace=True)

# %%
##CODE HERE

# %% [markdown]
# ### 3D. Null value imputation for totchol_column

# %%
##CODE HERE
df["totChol"].fillna(df['totChol'].mean(),inplace=True)

# %% [markdown]
# ### 3E. Null value imputation for BMI_column

# %%
##CODE HERE
df["BMI"].fillna(df['BMI'].mean(),inplace=True)

# %% [markdown]
# ### 3F. Null value imputation for heartRate_column

# %%
##CODE HERE
df["heartRate"].fillna(df['heartRate'].mean(),inplace=True)

# %% [markdown]
# ### 3G. Null value imputation for glucose_column

# %%
##CODE HERE
df["glucose"].fillna(df['glucose'].mean(),inplace=True)

# %%
##CODE HERE

# %% [markdown]
# ### 4. check the datatypes for the columns and correct the datatype

# %%
## CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4240 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4240 non-null   float64
#  5   BPMeds           4240 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4240 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4240 non-null   float64
#  13  heartRate        4240 non-null   float64
#  14  glucose          4240 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
##CODE HERE

# %%
##CODE HERE

# %% [markdown]
# ### 5A. Splitting The Data

# %%
y = df.TenYearCHD

# %%
x = df.iloc[:,:-1]

# %%
##CODE HERE
X_cat = df[['male',"education","currentSmoker","prevalentStroke","prevalentHyp","diabetes"]]

X_cat.head()
# Out:
#    male  education  currentSmoker  prevalentStroke  prevalentHyp  diabetes
# 0     1        4.0              0                0             0         0
# 1     0        2.0              0                0             0         0
# 2     1        1.0              1                0             0         0
# 3     0        3.0              1                0             1         0
# 4     0        3.0              1                0             0         0

# %%
##CODE HERE
X_num = df[["age","cigsPerDay","BPMeds","totChol","sysBP","diaBP","BMI","heartRate","glucose"]]
X_num.head()
# Out:
#    age  cigsPerDay  BPMeds  totChol  sysBP  diaBP    BMI  heartRate  glucose
# 0   39         0.0     0.0    195.0  106.0   70.0  26.97       80.0     77.0
# 1   46         0.0     0.0    250.0  121.0   81.0  28.73       95.0     76.0
# 2   48        20.0     0.0    245.0  127.5   80.0  25.34       75.0     70.0
# 3   61        30.0     0.0    225.0  150.0   95.0  28.58       65.0    103.0
# 4   46        23.0     0.0    285.0  130.0   84.0  23.10       85.0     85.0

# %% [markdown]
# ### 5B. Apply Data Transformations.
#
# Hint: Use Standardization technique or Normalization technique

# %%
## CODE HERE
X_concat = pd.concat([X_cat, X_num], axis=1)

X_concat.head()
# Out:
#    male  education  currentSmoker  prevalentStroke  prevalentHyp  diabetes  \
# 0     1        4.0              0                0             0         0
# 1     0        2.0              0                0             0         0
# 2     1        1.0              1                0             0         0
# 3     0        3.0              1                0             1         0
# 4     0        3.0              1                0             0         0
#
#    age  cigsPerDay  BPMeds  totChol  sysBP  diaBP    BMI  heartRate  glucose
# 0   39         0.0     0.0    195.0  106.0   70.0  26.97       80.0     77.0
# 1   46         0.0     0.0    250.0  121.0   81.0  28.73       95.0     76.0
# 2   48        20.0     0.0    245.0  127.5   80.0  25.34       75.0     70.0
# 3   61        30.0     0.0    225.0  150.0   95.0  28.58       65.0    103.0
# 4   46        23.0     0.0    285.0  130.0   84.0  23.10       85.0     85.0

# %% [markdown]
# ### 5C. Split The Data into Train and Test

# %%
##CODE HERE
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_concat, y, test_size = 0.30, random_state = 143)

# %%
X_train.head()
# Out:
#       male  education  currentSmoker  prevalentStroke  prevalentHyp  diabetes  \
# 2967     0        2.0              1                0             0         0
# 3073     1        3.0              0                0             0         0
# 1595     0        3.0              0                0             1         0
# 4204     0        2.0              0                0             0         0
# 1109     0        3.0              0                0             1         0
#
#       age  cigsPerDay  BPMeds  totChol  sysBP  diaBP    BMI  heartRate  \
# 2967   44         3.0     0.0    244.0  105.0   60.0  23.24       76.0
# 3073   46         0.0     0.0    297.0  133.0   92.0  25.98       69.0
# 1595   62         0.0     0.0    249.0  176.0   89.0  24.49       75.0
# 4204   38         0.0     0.0    216.0  142.0   72.0  22.01       63.0
# 1109   40         0.0     0.0    159.0  145.0   90.0  20.33       82.0
#
#         glucose
# 2967  81.963655
# 3073  64.000000
# 1595  81.000000
# ...

# %%
X_train_num = X_train.iloc[:,6:]
X_train_num.head()
# Out:
#       age  cigsPerDay  BPMeds  totChol  sysBP  diaBP    BMI  heartRate  \
# 2967   44         3.0     0.0    244.0  105.0   60.0  23.24       76.0
# 3073   46         0.0     0.0    297.0  133.0   92.0  25.98       69.0
# 1595   62         0.0     0.0    249.0  176.0   89.0  24.49       75.0
# 4204   38         0.0     0.0    216.0  142.0   72.0  22.01       63.0
# 1109   40         0.0     0.0    159.0  145.0   90.0  20.33       82.0
#
#         glucose
# 2967  81.963655
# 3073  64.000000
# 1595  81.000000
# 4204  75.000000
# 1109  83.000000

# %%
X_train_cat = X_train.iloc[:,:6]
X_train_cat.head()
# Out:
#       male  education  currentSmoker  prevalentStroke  prevalentHyp  diabetes
# 2967     0        2.0              1                0             0         0
# 3073     1        3.0              0                0             0         0
# 1595     0        3.0              0                0             1         0
# 4204     0        2.0              0                0             0         0
# 1109     0        3.0              0                0             1         0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_num_scaled = pd.DataFrame(scaler.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)
x_num_scaled.head()
# Out:
#            age  cigsPerDay    BPMeds   totChol     sysBP     diaBP       BMI  \
# 2967 -0.650789   -0.504618 -0.181842  0.153529 -1.240261 -1.901853 -0.620276
# 3073 -0.418031   -0.759184 -0.181842  1.326515  0.025909  0.757077  0.060246
# 1595  1.444031   -0.759184 -0.181842  0.264188  1.970384  0.507802 -0.309819
# 4204 -1.349062   -0.759184 -0.181842 -0.466162  0.432892 -0.904754 -0.925766
# 1109 -1.116304   -0.759184 -0.181842 -1.727675  0.568553  0.590893 -1.343020
#
#       heartRate   glucose
# 2967  -0.004179  0.003433
# 3073  -0.572052 -0.786093
# 1595  -0.085303 -0.038921
# 4204  -1.058801 -0.302629
# 1109   0.482570  0.048982

# %%
X_transformed_train = pd.concat([X_train_cat,x_num_scaled], axis=1)

X_transformed_train.head()
# Out:
#       male  education  currentSmoker  prevalentStroke  prevalentHyp  diabetes  \
# 2967     0        2.0              1                0             0         0
# 3073     1        3.0              0                0             0         0
# 1595     0        3.0              0                0             1         0
# 4204     0        2.0              0                0             0         0
# 1109     0        3.0              0                0             1         0
#
#            age  cigsPerDay    BPMeds   totChol     sysBP     diaBP       BMI  \
# 2967 -0.650789   -0.504618 -0.181842  0.153529 -1.240261 -1.901853 -0.620276
# 3073 -0.418031   -0.759184 -0.181842  1.326515  0.025909  0.757077  0.060246
# 1595  1.444031   -0.759184 -0.181842  0.264188  1.970384  0.507802 -0.309819
# 4204 -1.349062   -0.759184 -0.181842 -0.466162  0.432892 -0.904754 -0.925766
# 1109 -1.116304   -0.759184 -0.181842 -1.727675  0.568553  0.590893 -1.343020
#
#       heartRate   glucose
# ...

# %% [markdown]
# ### for X_test

# %%
X_test.shape
# Out:
# (1272, 15)

# %%
X_test_num = X_test.iloc[:,6:]
X_test_num.head()
# Out:
#       age  cigsPerDay  BPMeds  totChol  sysBP  diaBP    BMI  heartRate  \
# 3879   40        40.0     0.0    334.0  120.0   77.0  22.66       82.0
# 340    58         0.0     0.0    200.0  158.0  101.0  23.06       85.0
# 4127   48         0.0     0.0    287.0  155.0   80.0  28.54       75.0
# 324    43         0.0     0.0    200.0  133.0   78.0  26.72       55.0
# 351    49         5.0     0.0    187.0  110.0   67.0  19.26       78.0
#
#       glucose
# 3879     92.0
# 340      77.0
# 4127     75.0
# 324      71.0
# 351      85.0

# %%
X_test_cat = X_test.iloc[:,:6]
X_test_cat.head()
# Out:
#       male  education  currentSmoker  prevalentStroke  prevalentHyp  diabetes
# 3879     1        4.0              1                0             0         0
# 340      0        1.0              0                0             1         0
# 4127     0        1.0              0                0             0         0
# 324      1        3.0              0                0             0         0
# 351      1        2.0              1                0             0         0

# %%
from sklearn.preprocessing import StandardScaler
x_num_test = pd.DataFrame(scaler.transform(X_test_num), 
                                    columns = X_test_num.columns, 
                                    index = X_test_num.index)
x_num_test.head()
# Out:
#            age  cigsPerDay    BPMeds   totChol     sysBP     diaBP       BMI  \
# 3879 -1.116304    2.635030 -0.181842  2.145392 -0.561956 -0.489297 -0.764328
# 340   0.978516   -0.759184 -0.181842 -0.820271  1.156418  1.504900 -0.664982
# 4127 -0.185273   -0.759184 -0.181842  1.105197  1.020757 -0.240022  0.696062
# 324  -0.767167   -0.759184 -0.181842 -0.820271  0.025909 -0.406205  0.244037
# 351  -0.068894   -0.334907 -0.181842 -1.107984 -1.014159 -1.320212 -1.608772
#
#       heartRate   glucose
# 3879   0.482570  0.444543
# 340    0.725945 -0.214726
# 4127  -0.085303 -0.302629
# 324   -1.707800 -0.478434
# 351    0.158071  0.136884

# %%
X_transformed_test = pd.concat([X_test_cat,x_num_test], axis=1)

X_transformed_test.head()
# Out:
#       male  education  currentSmoker  prevalentStroke  prevalentHyp  diabetes  \
# 3879     1        4.0              1                0             0         0
# 340      0        1.0              0                0             1         0
# 4127     0        1.0              0                0             0         0
# 324      1        3.0              0                0             0         0
# 351      1        2.0              1                0             0         0
#
#            age  cigsPerDay    BPMeds   totChol     sysBP     diaBP       BMI  \
# 3879 -1.116304    2.635030 -0.181842  2.145392 -0.561956 -0.489297 -0.764328
# 340   0.978516   -0.759184 -0.181842 -0.820271  1.156418  1.504900 -0.664982
# 4127 -0.185273   -0.759184 -0.181842  1.105197  1.020757 -0.240022  0.696062
# 324  -0.767167   -0.759184 -0.181842 -0.820271  0.025909 -0.406205  0.244037
# 351  -0.068894   -0.334907 -0.181842 -1.107984 -1.014159 -1.320212 -1.608772
#
#       heartRate   glucose
# ...

# %% [markdown]
# ### 6A. Apply The Logistic Regression Model.

# %%
##CODE HERE
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_transformed_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(X_transformed_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
##CODE HERE

# %% [markdown]
# ### 6B.Find best threshold value using Log-Loss

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
## CODE HERE
pred = []

for model in [classifier]:
    pred.append(pd.Series(model.predict_proba(X_transformed_test)[:,1]))

final_pred = pd.concat(pred, axis=1).mean(axis=1)
print(" test roc-auc:{}".format(roc_auc_score(y_test,final_pred))) 
False_pos_rate, True_pos_rate, threshold = roc_curve(y_test, final_pred)

threshold
# Out:
#  test roc-auc:0.7444828968650781
# array([1.91106914, 0.91106914, 0.61180243, 0.59081002, 0.58126873,
#        0.56257524, 0.53641622, 0.53263044, 0.5008817 , 0.49959186,
#        0.47790867, 0.46661315, 0.46655263, 0.46553153, 0.4626788 ,
#        0.43748755, 0.43659339, 0.42963121, 0.42637295, 0.41096101,
#        0.41037907, 0.39632977, 0.39492447, 0.39138558, 0.38745756,
#        0.3848664 , 0.38470129, 0.37935863, 0.37808649, 0.37765873,
#        0.37547509, 0.3660429 , 0.36532429, 0.35830537, 0.35583404,
#        0.35342046, 0.34564849, 0.3452363 , 0.34225679, 0.33927015,
#        0.33499744, 0.32697952, 0.32681319, 0.32443371, 0.32427521,
#        0.32035389, 0.32011753, 0.31940112, 0.31811462, 0.31685971,
#        0.31538293, 0.31513059, 0.31512987, 0.31437959, 0.31254731,
#        0.30781203, 0.30537551, 0.30055154, 0.29915645, 0.29368701,
#        0.29297521, 0.2929744 , 0.29279623, 0.28743702, 0.28681876,
# ...

# %% [markdown]
# ### Accuracy

# %%
##CODE HERE
from sklearn.metrics import accuracy_score

acc = []

for thres in threshold:
    y_pred = np.where(final_pred>thres,1,0)

    #what ever prediction i am getting and if it is greater than threshold i'll be converting as 1 or i'll keep it as 0.




    acc.append(accuracy_score(y_test,y_pred,normalize=True))

    #Then i'll be computing my accuracy score with my y_test and then
    #append the accuracy inside acc list.



acc = pd.concat([pd.Series(threshold), pd.Series(acc)], axis=1)
acc.columns = ['threshold','accuracy']
acc.sort_values(by="accuracy", ascending=False, inplace = True)
acc.head()
# Out:
#     threshold  accuracy
# 9    0.499592  0.850629
# 8    0.500882  0.849843
# 10   0.477909  0.849843
# 7    0.532630  0.848270
# 11   0.466613  0.848270

# %% [markdown]
# ### 6C. Find ROC_AUC for Logistic regression

# %%
## CODE HERE
##CODE HERE
from sklearn.metrics import roc_auc_score, roc_curve 
lg_ytrain_pred = classifier.predict_proba(X_transformed_train)
print("LG Train roc-auc:{}".format(roc_auc_score(y_train, lg_ytrain_pred[:,1])))

lg_y_test_pred = classifier.predict_proba(X_transformed_test)
print("LG Test roc-auc:{}".format(roc_auc_score(y_test, lg_y_test_pred[:,1])))
# Out:
# LG Train roc-auc:0.724474092499419
# LG Test roc-auc:0.7444828968650781

# %%
## CODE HERE
pred = []

for model in [classifier]:
    pred.append(pd.Series(model.predict_proba(X_transformed_test)[:,1]))

final_pred = pd.concat(pred, axis=1).mean(axis=1)
print(" test roc-auc:{}".format(roc_auc_score(y_test,final_pred)))
# Out:
#  test roc-auc:0.7444828968650781

# %%
import matplotlib.pyplot as plt
def plot_roc_curve(False_pos_rate,True_pos_rate):
    plt.plot(False_pos_rate, True_pos_rate, label="ROC")
    plt.plot([0,1],[0,1],color="Red",linestyle="--")
    plt.xlabel("False_Positive_rate")
    plt.ylabel("True_Positive_rate")
    plt.title("ROC Curve")
    plt.legend
    plt.show()

plot_roc_curve(False_pos_rate,True_pos_rate)

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
 
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[   1 1068]
#  [   0  203]]

# %% [markdown]
# ### 7. Apply Decision Tree model

# %%
## CODE HERE
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_transformed_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
## CODE HERE
y_pred = classifier.predict(X_transformed_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %% [markdown]
# ### 8. Visualize the tree

# %%
## CODE HERE

# %% [markdown]
# ### 9. Find The Classification Metrics and Give the Observations to Metric for above algorithms
# - Confusion Matrix
#     - Precision
#     - Recall
#     - Specificity
#     - Sensitivity
#     - Accuracy
#     - F1-score
#     - True Positive Rate
#     - False Positive Rate
# - Classification Report
# - ROC_AUC Curve

# %% [markdown]
# ### test accuracy

# %%
##CODE HERE
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.7625786163522013

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, roc_auc_score, precision_score, classification_report

clf = DecisionTreeClassifier(class_weight="balanced")
clf.fit(X_train, y_train)

THRESHOLD = 0.61
preds = np.where(clf.predict_proba(X_test)[:,1] > THRESHOLD, 1, 0)

pd.DataFrame(data=[accuracy_score(y_test, preds), recall_score(y_test, preds), precision_score(y_test, preds), roc_auc_score(y_test, preds)], index=["accuracy", "recall", "precision", "roc_auc_score"])
# Out:
#                       0
# accuracy       0.746069
# recall         0.246305
# precision      0.227273
# roc_auc_score  0.543639

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85      1069
#            1       0.23      0.25      0.24       203
#
#     accuracy                           0.75      1272
#    macro avg       0.54      0.54      0.54      1272
# weighted avg       0.75      0.75      0.75      1272

# %%
False_pos_rate, True_pos_rate, threshold = roc_curve(y_test, final_pred)

threshold
# Out:
# array([1.91106914, 0.91106914, 0.61180243, 0.59081002, 0.58126873,
#        0.56257524, 0.53641622, 0.53263044, 0.5008817 , 0.49959186,
#        0.47790867, 0.46661315, 0.46655263, 0.46553153, 0.4626788 ,
#        0.43748755, 0.43659339, 0.42963121, 0.42637295, 0.41096101,
#        0.41037907, 0.39632977, 0.39492447, 0.39138558, 0.38745756,
#        0.3848664 , 0.38470129, 0.37935863, 0.37808649, 0.37765873,
#        0.37547509, 0.3660429 , 0.36532429, 0.35830537, 0.35583404,
#        0.35342046, 0.34564849, 0.3452363 , 0.34225679, 0.33927015,
#        0.33499744, 0.32697952, 0.32681319, 0.32443371, 0.32427521,
#        0.32035389, 0.32011753, 0.31940112, 0.31811462, 0.31685971,
#        0.31538293, 0.31513059, 0.31512987, 0.31437959, 0.31254731,
#        0.30781203, 0.30537551, 0.30055154, 0.29915645, 0.29368701,
#        0.29297521, 0.2929744 , 0.29279623, 0.28743702, 0.28681876,
#        0.28622136, 0.28597699, 0.28511883, 0.28283936, 0.2805581 ,
# ...

# %%
from sklearn.metrics import accuracy_score

acc = []

for thres in threshold:
    y_pred = np.where(final_pred>thres,1,0)

    #what ever prediction i am getting and if it is greater than threshold i'll be converting as 1 or i'll keep it as 0.




    acc.append(accuracy_score(y_test,y_pred,normalize=True))

    #Then i'll be computing my accuracy score with my y_test and then
    #append the accuracy inside acc list.



acc = pd.concat([pd.Series(threshold), pd.Series(acc)], axis=1)
acc.columns = ['threshold','accuracy']
acc.sort_values(by="accuracy", ascending=False, inplace = True)
acc.head()
# Out:
#     threshold  accuracy
# 9    0.499592  0.850629
# 8    0.500882  0.849843
# 10   0.477909  0.849843
# 7    0.532630  0.848270
# 11   0.466613  0.848270

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix : ", cm)
# Out:
# Confusion Matrix :  [[   1 1068]
#  [   0  203]]
